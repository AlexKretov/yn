# %%
from sqlalchemy import create_engine
import os
import numpy as np
import pandas as pd
from dotenv import load_dotenv

def create_connection():

    load_dotenv()
    host = os.environ.get('DB_DESTINATION_HOST')
    port = os.environ.get('DB_DESTINATION_PORT')
    db = os.environ.get('DB_DESTINATION_NAME')
    username = os.environ.get('DB_DESTINATION_USER')
    password = os.environ.get('DB_DESTINATION_PASSWORD')
    
    print(f'postgresql://{username}:{password}@{host}:{port}/{db}')
    conn = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{db}')
    return conn

# устанавливаем соединение с базой
conn = create_connection()
# Out:
# postgresql://mle_20250130_833968fcc1:89973ec6fc2c425581318d5c8083b7f3@rc1b-uh7kdmcx67eomesf.mdb.yandexcloud.net:6432/playground_mle_20250130_833968fcc1

# %%
sql ='''
SELECT
    f.id as flat_id,
    floor,
    is_apartment,
    kitchen_area,
    living_area,
    rooms,
    studio,
    total_area,
    price,
    build_year,
    building_type_int,
    latitude,
    longitude,
    ceiling_height,
    flats_count,
    floors_total,
    has_elevator

FROM
    flats f
    left join buildings b on b.id = f.building_id 
    
'''
data = pd.read_sql(sql, conn)
print(f'data shape = {data.shape}') 
tables = conn.table_names()
print(tables)
data.head()
# Out:
# data shape = (141362, 17)
# ['clean_users_churn', 'buildings', 'flats', 'users_churn', 'alt_users_churn']
# /tmp/ipykernel_4280/1618091392.py:28: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   tables = conn.table_names()
#    flat_id  floor  is_apartment  kitchen_area  living_area  rooms  studio  \
# 0        0      9         False           9.9    19.900000      1   False
# 1        1      7         False           0.0    16.600000      1   False
# 2        2      9         False           9.0    32.000000      2   False
# 3        3      1         False          10.1    43.099998      3   False
# 4        4      3         False           3.0    14.000000      1   False
#
#    total_area     price  build_year  building_type_int   latitude  longitude  \
# 0   35.099998   9500000        1965                  6  55.717113  37.781120
# ...

# %%
for c in data.columns:
    print(f'{c} = {data[c].max()}')
# Out:
# flat_id = 141361
# floor = 56
# is_apartment = True
# kitchen_area = 203.0
# living_area = 700.0
# rooms = 20
# studio = False
# total_area = 960.2999877929688
# price = 9873737728
# build_year = 2023
# building_type_int = 6
# latitude = 56.01103210449219
# longitude = 37.9464111328125
# ceiling_height = 27.0
# flats_count = 4455
# floors_total = 99
# has_elevator = True

# %% [markdown]
# 4294967295
# 9873737728

# %%
data.describe()
# Out:
#              flat_id          floor   kitchen_area    living_area  \
# count  141362.000000  141362.000000  141362.000000  141362.000000
# mean    70680.500000       7.467346       9.001579      31.056948
# std     40807.838714       5.717144       5.264076      23.968640
# min         0.000000       1.000000       0.000000       0.000000
# 25%     35340.250000       3.000000       6.100000      19.000000
# 50%     70680.500000       6.000000       8.800000      29.400000
# 75%    106020.750000      10.000000      10.200000      41.400002
# max    141361.000000      56.000000     203.000000     700.000000
#
#                rooms     total_area         price     build_year  \
# count  141362.000000  141362.000000  1.413620e+05  141362.000000
# mean        2.129476      62.374644  1.944162e+07    1986.600048
# std         0.994340      40.295864  6.626954e+07      22.136409
# min         1.000000      11.000000  1.100000e+01    1901.000000
# ...

# %%
sql ='''
SELECT column_name, data_type
FROM information_schema.columns WHERE table_name = 'flats'
'''
typo = pd.read_sql(sql, conn)
typo
# Out:
#     column_name         data_type
# 0            id            bigint
# 1         floor            bigint
# 2  is_apartment           boolean
# 3  kitchen_area  double precision
# 4   living_area  double precision
# 5         rooms            bigint
# 6        studio           boolean
# 7    total_area  double precision
# 8         price            bigint
# 9   building_id            bigint

# %%
sql ='''
SELECT *
FROM flat_dataset LIMIT 10
'''
typo = pd.read_sql(sql, conn)
typo
# Out:
#        id  flat_id  floor is_apartment  kitchen_area  living_area  rooms  \
# 0   39430    13620      2        false          0.00    40.099998      3
# 1   39432    13621      8        false          9.00    36.000000      2
# 2   39434    13622     12        false          8.00    18.000000      1
# 3   39436    13623      2        false          6.00    41.000000      3
# 4   39438    13624     12        false          0.00     0.000000      2
# 5   39440    13625      8        false         12.00    48.000000      3
# 6   39442    13626      3        false          7.00    43.299999      3
# 7   39444    13627      2        false          0.00    44.900002      3
# 8   39446    13628      7        false          8.58    30.350000      2
# 9  101548    44839     15        false          9.00    18.000000      1
#
#   studio  total_area     price  build_year  building_type_int  living_cluster  \
# 0  false   65.699997  12500000        1975                  4               3
# ...

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import TargetEncoder
from sklearn.preprocessing import OneHotEncoder
from catboost import CatBoostRegressor
from sklearn.impute import SimpleImputer
import yaml
import os
import joblib

# обучение модели
def fit_model():
    # Прочитайте файл с гиперпараметрами params.yaml
    with open('/home/mle-user/mle_projects/yn/params.yaml', 'r') as fd:
        params = yaml.safe_load(fd)
    print('Params loaded sucessfully')
    # загрузите результат предыдущего шага: inital_data.csv
    data = pd.read_csv('/home/mle-user/mle_projects/yn/data/initial_data.csv')
    print('Data loaded sucessfully')
    data = data.drop(['id','flat_id'], axis=1)
    # Построение пайплайна
    cat_features = data.select_dtypes(include=['object','bool'])
    cats=cat_features.columns.tolist()
    for c in cats:
        data[c]=data[c].astype('category')
    fit_params = {
        'learning_rate': params['learning_rate'],
        'min_child_samples': params['min_child_samples'],
        'depth': params['depth'],
        'loss_function': params['loss_function'],
        'random_state': params['random_state'],
    }
    model = CatBoostRegressor(**fit_params, cat_features=cats)

    model.fit(data.drop([params['target_col']], axis=1), data[params['target_col']]) 
    print('Model  fitted sucessfully')
    os.makedirs('models', exist_ok=True)
    # сохраните обученную модель в models/fitted_model.pkl
    with open('models/fitted_model0.pkl', 'wb') as fd:
        joblib.dump(model, fd)
    print('Model saved sucessfully!')
if __name__ == '__main__':
    fit_model()
# Out:
# Params loaded sucessfully
# Data loaded sucessfully
# 0:	learn: 4727962.0650734	total: 77.4ms	remaining: 1m 17s
# 1:	learn: 4472201.8185384	total: 175ms	remaining: 1m 27s
# 2:	learn: 4246440.2959558	total: 292ms	remaining: 1m 36s
# 3:	learn: 4057229.6781384	total: 373ms	remaining: 1m 32s
# 4:	learn: 3893141.7601202	total: 422ms	remaining: 1m 23s
# 5:	learn: 3750543.8653711	total: 459ms	remaining: 1m 16s
# 6:	learn: 3627388.3773528	total: 533ms	remaining: 1m 15s
# 7:	learn: 3523977.0711367	total: 609ms	remaining: 1m 15s
# 8:	learn: 3430741.3527655	total: 651ms	remaining: 1m 11s
# 9:	learn: 3350140.3871819	total: 692ms	remaining: 1m 8s
# 10:	learn: 3280349.6292614	total: 763ms	remaining: 1m 8s
# 11:	learn: 3222495.3882309	total: 814ms	remaining: 1m 7s
# 12:	learn: 3173368.6789533	total: 856ms	remaining: 1m 4s
# 13:	learn: 3131897.6260407	total: 906ms	remaining: 1m 3s
# 14:	learn: 3090967.2529604	total: 964ms	remaining: 1m 3s
# 15:	learn: 3058457.4273720	total: 1.06s	remaining: 1m 4s
# ...
